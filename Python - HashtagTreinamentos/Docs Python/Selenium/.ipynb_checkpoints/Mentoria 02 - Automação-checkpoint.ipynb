# %% [markdown]
# ### Passo 1: Iniciando o Navegador no site que queremos

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

driver = webdriver.Chrome()
#driver = webdriver.Chrome(option='headless') // sem abrir o navegador
driver.get('https://www.kaggle.com/sakshigoyal7/credit-card-customers')

# %% [markdown]
# ### Passo 2: Fazer o download do Arquivo

# %%
driver.find_elements_by_css_selector('a.sc-jXcxbT')[0].click() #botao de download
# Out:
# <ipython-input-13-8c306def2a3c>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   driver.find_elements_by_css_selector('a.sc-jXcxbT')[0].click() #botao de download

# %%
driver.find_elements_by_css_selector('a.sc-gpEJdM')[1].click() #botao de login com email
# Out:
# <ipython-input-14-eba43f0c6a66>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   driver.find_elements_by_css_selector('a.sc-gpEJdM')[1].click() #botao de login com email

# %%
driver.find_elements_by_css_selector('input.mdc-text-field__input')[0].send_keys('lucasramalho.rdash@gmail.com') #preencher o email de login
driver.find_elements_by_css_selector('input.mdc-text-field__input')[1].send_keys('Teste123*') #preencher a senha
driver.find_elements_by_css_selector('button.sc-eEVmNe')[0].click()
# Out:
# <ipython-input-15-98d730735831>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   driver.find_elements_by_css_selector('input.mdc-text-field__input')[0].send_keys('lucasramalho.rdash@gmail.com') #preencher o email de login
# <ipython-input-15-98d730735831>:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   driver.find_elements_by_css_selector('input.mdc-text-field__input')[1].send_keys('Teste123*') #preencher a senha
# <ipython-input-15-98d730735831>:3: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   driver.find_elements_by_css_selector('button.sc-eEVmNe')[0].click()

# %%
driver.find_elements_by_css_selector('a.sc-jXcxbT')[0].click() #botao de download
# Out:
# <ipython-input-16-8c306def2a3c>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   driver.find_elements_by_css_selector('a.sc-jXcxbT')[0].click() #botao de download

# %% [markdown]
# ### Passo 3: Unzipar o Arquivo (Extrair da pasta zip)

# %%
import zipfile

with zipfile.ZipFile(r'C:\Users\lucas\Downloads\archive.zip', 'r') as zip_ref:
    zip_ref.extractall(r'C:\Users\lucas\Downloads')

# %% [markdown]
# ### Passo 4: Importar o arquivo pro nosso computador com o pandas

# %%
import pandas as pd

clientes_df = pd.read_csv(r'C:\Users\lucas\Downloads\BankChurners.csv')
display(clientes_df)
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %% [markdown]
# ### Passo 5: Calcular os indicadores para enviar para a diretoria:
#
#     1 - Quantos clientes Ativos e Quantos Clientes em Disputa Temos?
#     2 - Dos Clientes Ativos, como está a distribuição por tipo de cartão
#     3 - Qual o tempo médio de permanência e o limite de crédito médio dos nosso clientes (totais e ex-clientes)?

# %%
# 1
resumo_status = clientes_df.groupby('Attrition_Flag')['Attrition_Flag'].count()
print(resumo_status.to_string())
# Out:
# Attrition_Flag
# Attrited Customer    1627
# Existing Customer    8500

# %%
#2

clientes_ativos = clientes_df.loc[clientes_df['Attrition_Flag'] == 'Existing Customer', ['Attrition_Flag', 'Card_Category']]
#display(clientes_ativos)

resumo_cartoes = clientes_ativos.groupby('Card_Category')['Card_Category'].count()
resumo_cartoes.index.names = ['Categoria do Card - Existing Customers']
print(resumo_cartoes.to_string())
print('Clientes Totais: {}'.format(clientes_ativos['Card_Category'].count()))
# Out:
# Categoria do Card - Existing Customers
# Blue        7917
# Gold          95
# Platinum      15
# Silver       473
# Clientes Totais: 8500

# %%
#3
tempo_medio = clientes_df['Months_on_book'].mean()
print(f'Tempo Medio: {tempo_medio:.1f}')

#limite todo mundo
limite_todomundo = clientes_df['Credit_Limit'].mean()

#limite ex clientes
ex_clientes = clientes_df.loc[clientes_df['Attrition_Flag'] == 'Attrited Customer', ['Attrition_Flag', 'Credit_Limit']] 
limite_exclientes = ex_clientes['Credit_Limit'].mean()
print(limite_todomundo)
print(limite_exclientes)
# Out:
# Tempo Medio: 35.9
# 8631.953698034848
# 8136.03945912722

# %% [markdown]
# ### Passo 6: Enviar e-mail para chefe

# %%
import win32com.client as win32

outlook = win32.Dispatch('outlook.application')
mail = outlook.CreateItem(0)

mail.To = 'lucasramalho.rdash@gmail.com'
mail.Subject = 'Relatório de Clientes - Análise de Attrited Customers'
mail.Body = f'''
Olá Lucas, tudo bem?

Conforme solicitado, levantamos os principais indicadores dos nossos clientes para ver o impacto dos Attrited Customers.

Temos atualmente a seguinte divisão da base de clientes:

{resumo_status.to_string()}

Quando analisamos os clientes ativos (Existing Customers) percebemos a seguinte divisão de categorias de cartão:

{resumo_cartoes.to_string()}

Já quanto ao tempo médio de permanência dos clientes temo em média {tempo_medio:.1f} meses.

Por fim, quando comparamos o limite de crédito médio dos clientes atuais e antigos, não temos muita diferença, ficando com {limite_todomundo:.1f} para os atuais e {limite_exclientes:.1f} para os antigos.

Segue em anexo o relatório completo para mais detalhes.

Qualquer dúvida estou à disposição.

Att.,
Lucas Ramalho
'''

# Anexos (pode colocar quantos quiser):
attachment  = r'C:\Users\lucas\Downloads\BankChurners.csv'
mail.Attachments.Add(attachment)

mail.Send()
